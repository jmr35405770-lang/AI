# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# <font size="6" color="red">ch02. 자료형과 연산자</font>
#
# # 1절. 변수
# (변수 : 프로그램 작업 처리를 위해, 값을 저장할 수 있는 메모리 공간)
# - 파이썬은 변수 선언을 위한 타입이 없고, 별도의 선언 과정도 없음
#
# ## 1.1 변수 할당
# - 할당연산자(=)를 이용해서 값을 할당하면 타입이 셋팅
# - 파이썬에서의 모든 변수는 객체로 저장

# %%
r = 5
area = 3.14* r * r
print('계산된 넓이는', area)
# Out:
# 계산된 넓이는 78.5

# %%
import numpy as np # numpy라는 패키지 (폴더)를 np 라는 이름으로 사용

# %%
area = np.pi * r * r

# %%
r = 4
print('계산된 넓이는',area)
# Out:
# 계산된 넓이는 78.53981633974483

# %%
print('area주소 :', id(area))
print('area타입', type(area))
# Out:
# area주소 : 2196586137360
# area타입 <class 'float'>

# %%
area = 10
print('area주소', id(area))
print('area타입', type(area))
# Out:
# area주소 2196506804752
# area타입 <class 'int'>

# %%
area = "파이썬"
print('area주소', id(area))
print('area타입', type(area))
# Out:
# area주소 2196611895472
# area타입 <class 'str'>

# %% [markdown]
# ## 1.2 변수이름 규칙
# - 문자로(특수문자는 _를 제회하고는 안됨)로 시작
# - 문자, 숫자, _로 변수명 작성
# - 함수명은 변수명으로 가능하나 피한다. 꼭 써야한다면 str_식으로 _를 붙혀 사용
# - 파이썬 에약어(for, if , ...)는 변수이름 사용 불가
# - 한글변수는 꼭 필요시에만 사용

# %%
이름 = "홍길동" # 비추
print(이름)
# Out:
# 홍길동

# %%
for i in range(10):
    print

# %%
print = 10
print(1)
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 print = 10
# ----> 2 print(1)
#
# TypeError: 'int' object is not callable

# %%
del print # 방법1 : print 변수 삭제(변수가 없을 경우 에러)
print(1)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 del print # 방법1 : print 변수 삭제(변수가 없을 경우 에러)
#       2 print(1)
#
# NameError: name 'print' is not defined

# %%
# 방법2 : 커널 재시작하면 커널 초기화
# %whos
# Out:
# Interactive namespace is empty.

# %%
print(1)
# Out:
# 1

# %% [markdown]
# ## 1.3 도움말

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
help() # hepl바져 나오려면 q / ESC + o 접기/펴기
# Out:
# Welcome to Python 3.10's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the internet at https://docs.python.org/3.10/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> print
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
# ...

# %%
# 주피터 노트북에서의 도움말 기능 : 함수 괄호 안에서 shift +tab,tab 키
print()

# %%
def add(x, y=0):
    ''' 
    매개변수 2개를 받아 두자리 숫자로 만들어요
    x = 10의 자리수가 됨
    y = 1의 자리수가 됨(default 값 0)
    사용법 : add(2, 3) => 23
    '''
    return x*10 + y

# %%
add(5, 4)
# Out:
# 54

# %%
add(5)
# Out:
# 50

# %%
a= add
a(5, 3)
# Out:
# 53

# %% [markdown]
# # 1.4 다중 변수 선언

# %%
a = 10
b = 20

# %%
a, b = 10, 20 # 동시에 다중 변수 선언과 할당

# %%
print(a, b)
# Out:
# 10 20

# %%
a, b = b, a+b # 다중 변수 할당시 순차적 할당이 아니고 일괄 동시 할당

# %%
a, b
# Out:
# (20, 30)

# %% [markdown]
# # 2절. 화면 i/o

# %%
# input() : 사용자로부터 값을 입력받기 위한 함수. 입력값은 문자열
first = input('첫번째 숫자는?')
first
# Out:
# 첫번째 숫자는?20
# '20'

# %%
# 두 수를 입력받아 합을 출력
first = int(input('첫번째 수?'))
second = int(input('두번째 수?'))
print('두 수의 합은', first+second)
# Out:
# 첫번째 수?20
# 두번째 수?10
# 두 수의 합은 30

# %%
print('수1', first, '수2', second, sep='/', end='\t')
print('합', first+second)
# Out:
# 수1/20/수2/10	합 30

# %% [markdown]
# # 3절 기본 자료형
# - 프로그래밍 언어들은 변수가 가져야 할 값의 형식, 범위는 자료형에 따라 다르다 = 자료형에 따라 값의 크기, 사용함수가 달라짐
# - 기본 자료형
#     * `숫자` - int(정수), float(실수), complex(허수부)
#     * `문자` - str
#     * `논리` - bool (true/False)
#
# ## 3.1 숫자형

# %%
import sys 
sys.maxsize
# Out:
# 9223372036854775807

# %%
2 ** 63 -1 # 2의 63승 -1
# Out:
# 9223372036854775807

# %%
i = sys.maxsize + 1000 # 파이썬이 처리할 수 있는 수의 범위는 X
print(i)
print(type(i))
# Out:
# 9223372036854776807
# <class 'int'>

# %%
f = 3/2 # 자바처럼 정수/정수를 정수로 출력(몫만 출력)
f = int(3/2) # int로 형변환
print(f)
f = 3//2 # 몫연산자
print(f)
# Out:
# 1
# 1

# %%
c = 1j #허수
c**2
# Out:
# (-1+0j)

# %%
# 너무 큰 수나 너무 작은 수는 지수형 표현으로 나타내기도 한다
f = 1.2e12 # 1.2 x 10의 12승
f
# Out:
# 1200000000000.0

# %% [markdown]
# ## 3.2 문자형
# - 겹따옴표("-")나 홑따옴표('-')이용

# %%
name1 = '홍길동\'짱\''
name2 = "홍길동'짱'"
print(name1 == name2) # name1과 name2가 같은지 여부
print(name1, name2)
# Out:
# True
# 홍길동'짱' 홍길동'짱'

# %%
# escape문자(탈출문자)
text = '여러줄짜리 문장입니다\n두번째\t문장입니다\n세번째\t문장입니다'
print(text)
# Out:
# 여러줄짜리 문장입니다
# 두번째	문장입니다
# 세번째	문장입니다

# %%
text = '''여러줄짜리 문장입니다
두번째 문장입니다
세번째 문장입니다
'''
print(text)
# Out:
# 여러줄짜리 문장입니다
# 두번째 문장입니다
# 세번째 문장입니다

# %% [markdown]
# ※ 문자열 연산

# %%
'''
    여러 줄 주석 용도
    2026.06.23 문자열 연산 by 홍길동
'''
name1 = "홍길동"
name2 = "박길동"
print(name1 + name2)
# Out:
# 홍길동박길동

# %%
print(name1 * 5)
# Out:
# 홍길동홍길동홍길동홍길동홍길동

# %% [markdown]
# ※ raw 데이터
# - 용도 : 디렉토리 경로 표현시 이용 / 정규표현식 이용

# %%
print('Hello\nWorld')
print(r'Hello\nWorld')
# Out:
# Hello
# World
# Hello\nWorld

# %% [markdown]
# 정규표현식(regex)
# ```(마크다운에서 백틱은블록을만들때사용)
#     1. 참조 : https://ko.wikipedia.org/wiki/정규_표현식 위키백과
#     2. 간략문법
#     \d : (숫자와매치. [0-9]와 동일)
#     \D : (숫자가아닌것)
#     \w : (영문자나숫자[a-zA-Z0-9]와 동일)
#     \W : (영문자나숫자가아닌문자)
#     . : (문자)
#     \. : (.)
#     \s : ( )
#     \- : (-)
#     {2,} : (2번 이상 반복)
#     {2, 4} : (2~4회 반복) #(4,4)는 불가능
#     ? : (0번이나 1번 의미)
#     + : (1번이상반복)
#     * : (0번이상반복)
#     3. 정규표현식연습장: https://regexr.com/
#     ex1. 전화번호 : 02 888 7777 / 028887777 / 010-9999-9999 / 010.9999.9999 /
#             02)999-9999
#             => 0\d{1,2}[ \-\.)]?\d{3,4}[ \-\.]?\d{4}
#     ex2. 이메일 : abc12@naver.com / abc12@sns.co.kr
#             => \w+@\w+(\.\w+){1,2}
#     ex3. 주민번호 : 981212-1052525
#         => \d{2}(0[1-9]|1[0-2])(0[1-9]|[12]\d|30|31)-[1-4]\d{6}
#     4. 소스 구현
# ```

# %%
data = "이름:홍길동, 주소:신림동, 전화:02-888-8888, \
핸드폰:010-9999-9999, 이메일:abc@lg.co.kr, 이메일:abc@naver.com\
특징:동해번쩍 서해번쩍, 혈액형:B ㅋㅋ"

# %%
import re
tel_pattern = r"0\d{1,2}[\-)\s\.]\d{3,4}[\-\s\.]\d{4}"
tels = re.findall(tel_pattern, data) # 해당 패턴을 다 찾아줘. 없으면 빈 list([])
tels
# Out:
# ['02-888-8888', '010-9999-9999']

# %%
# 정규표현식 패턴과 처음 match되는 것을 찾아줘
firstTel = re.search(tel_pattern, data)
firstTel
# Out:
# <re.Match object; span=(19, 30), match='02-888-8888'>

# %%
print(firstTel.group(0))
print(data[19:30])
# Out:
# 02-888-8888
# 02-888-8888

# %%
phone_pttern = r"(\d{2,3})-(\d{3,4})-(\d{4})"
phone = re.search(phone_pttern, data)
print(phone.group(0))
print(phone.group(1))
print(phone.group(2))
print(phone.group(3))
# Out:
# 02-888-8888
# 02
# 888
# 8888

# %%
email_pttern = r"\w[a-z0-9_]+@\w+(\.\w+){1,2}"
print(re.findall(email_pttern, data))
print(re.search(email_pttern, data).group(0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 email_pttern = r"\w[a-z0-9_]+@\w+(\.\w+){1,2}"
# ----> 2 print(re.findall(email_pttern, data))
#       3 print(re.search(email_pttern, data).group(0))
#
# NameError: name 're' is not defined

# %%
# 특정 문자외 없애기
re.sub(r"[^가-힣0-9\-a-z@]"," ", data)
# Out:
# '이름 홍길동  주소 신림동  전화 02-888-8888  핸드폰 010-9999-9999  이메일 abc@lg co kr  이메일 abc@naver com특징 동해번쩍 서해번쩍  혈액형     '
