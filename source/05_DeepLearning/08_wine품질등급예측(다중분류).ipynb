# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# # red wine 품질 등급 예측
# ```
# 1. 데이터 셋 확보 & 전처리
#     결측치 처리 -> 독립(입력)변수와 종속(타겟)변수를 분리 -> 독립변수의 스케일조정(StandardScaler)
#     -> 종속변수의 균형을 확인
#     -> 종속변수 원핫인코딩(pd.get_dummies) -> 훈련셋과 테스트셋분리(train_test_split)
# 2. 모델구성
# 3. 모델학습과정 설정(다중분류)
# 4. 모델학습(callback, compute_class_weight를 이용)
# 5. 모델평가(시각화, 평가, 교차표 - 테스트셋)
# 6. 모델 저장 / 예측
#
# ```
# ## 1. 데이터셋 확보 및 전처리

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.regularizers import l2
from tensorflow.keras import metrics # metrics.Recall, metrics.Precision
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, ReduceLROnPlateau
from matplotlib import pyplot as plt

# %%
redwine = pd.read_csv('data/winequality-red.csv', sep=';')
redwine.info() # 결측치 없음
# redwine = np.loadtxt('data/winequality-red.csv', delimiter=';', skiprows=1) 넘파이배열로
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# 독립(입력)변수와 종속(타겟)변수를 분리
X_redwine = redwine.iloc[:, :-1].to_numpy() #.values과 유사. numpy로 변경
y_redwine = redwine.iloc[:, -1]
X_redwine.shape, y_redwine.shape
# Out:
# ((1599, 11), (1599,))

# %%
# 독립변수의 스케일조정
scaler = StandardScaler()
# scaler.fit(X_redwine)
# scaled_X_redwine = scaler.transform(X_redwine)
scaled_X_redwine = scaler.fit_transform(X_redwine)

# %%
# 종속변수의 원핫인코딩
Y_redwine = pd.get_dummies(y_redwine).values
np.c_[y_redwine[2:4], Y_redwine[2:4]] # 원데이터와 원핫인코딩
# Out:
# array([[5, 0, 0, 1, 0, 0, 0],
#        [6, 0, 0, 0, 1, 0, 0]], dtype=int64)

# %%
# 종속변수의 균형을 확인
y_redwine.value_counts(normalize=True)
# Out:
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 4    0.033146
# 8    0.011257
# 3    0.006254
# Name: quality, dtype: float64

# %%
# 독립변수와 타겟변수
scaled_X_redwine.shape, Y_redwine.shape
# Out:
# ((1599, 11), (1599, 6))

# %%
# 훈련셋과 테스트셋 분리(층화추출) = 7 : 3
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X_redwine,
                                                   Y_redwine,
                                                   test_size=0.3,
                                                   #train_size=0.7,
                                                   stratify=Y_redwine, # 층화추출
                                                   random_state=12) # seed값
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((1119, 11), (480, 11), (1119, 6), (480, 6))

# %% [markdown]
# ## 2. 모델 구성
# - 입력 11 -> 64 -> 50 -> 30 -> 출력 6
# - He초기화 : 층이 깊을 때 활성화함수를 relu사용시

# %%
model = Sequential(name='sequential')
model.add(Input(11))
model.add(Dense(units=64, activation='relu', kernel_initializer=HeNormal(seed=42)))
model.add(Dense(units=50, activation='relu', kernel_initializer='he_normal'))
model.add(Dropout(0.1))
model.add(Dense(units=30, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(units=6, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 50)                3250
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_2 (Dense)             (None, 30)                1530
#
#  dense_3 (Dense)             (None, 6)                 186
#
# =================================================================
# Total params: 5,734
# Trainable params: 5,734
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy', # sparse_categorical_crossentropy
             optimizer='adam',
             metrics=['accuracy', 
                      metrics.Recall(name='recall'), 
                      metrics.Precision(name='precision')])

# %% [markdown]
# ## 4. 학습시키기
# - callbacks 이용

# %%
# %%time
earlyStopping = EarlyStopping(monitor='val_loss', patience=50)
hist = model.fit(X_train, Y_train,
                validation_split=0.2, # 학습셋의 20%를 검증셋으로
                # class_weight=class_weight_dict,
                callbacks=[earlyStopping],
                epochs=200, 
                verbose=2)
# Out:
# Epoch 1/200
# 28/28 - 2s - loss: 1.5146 - accuracy: 0.4615 - recall: 0.1475 - precision: 0.4583 - val_loss: 1.2999 - val_accuracy: 0.5000 - val_recall: 0.2545 - val_precision: 0.5700 - 2s/epoch - 60ms/step
# Epoch 2/200
# 28/28 - 0s - loss: 1.1287 - accuracy: 0.5397 - recall: 0.3575 - precision: 0.5970 - val_loss: 1.1880 - val_accuracy: 0.5089 - val_recall: 0.4062 - val_precision: 0.5688 - 86ms/epoch - 3ms/step
# Epoch 3/200
# 28/28 - 0s - loss: 1.0525 - accuracy: 0.5877 - recall: 0.4246 - precision: 0.6260 - val_loss: 1.1334 - val_accuracy: 0.5134 - val_recall: 0.4062 - val_precision: 0.5833 - 84ms/epoch - 3ms/step
# Epoch 4/200
# 28/28 - 0s - loss: 1.0030 - accuracy: 0.5911 - recall: 0.4503 - precision: 0.6336 - val_loss: 1.0879 - val_accuracy: 0.5089 - val_recall: 0.3973 - val_precision: 0.5855 - 98ms/epoch - 3ms/step
# Epoch 5/200
# 28/28 - 0s - loss: 0.9741 - accuracy: 0.5888 - recall: 0.4536 - precision: 0.6414 - val_loss: 1.0795 - val_accuracy: 0.5580 - val_recall: 0.3973 - val_precision: 0.6096 - 91ms/epoch - 3ms/step
# Epoch 6/200
# 28/28 - 0s - loss: 0.9568 - accuracy: 0.6067 - recall: 0.4458 - precision: 0.6404 - val_loss: 1.0836 - val_accuracy: 0.5089 - val_recall: 0.4286 - val_precision: 0.5926 - 95ms/epoch - 3ms/step
# Epoch 7/200
# 28/28 - 0s - loss: 0.9450 - accuracy: 0.6056 - recall: 0.4804 - precision: 0.6418 - val_loss: 1.0563 - val_accuracy: 0.5312 - val_recall: 0.4420 - val_precision: 0.6111 - 100ms/epoch - 4ms/step
# Epoch 8/200
# 28/28 - 0s - loss: 0.9020 - accuracy: 0.6190 - recall: 0.4927 - precision: 0.6572 - val_loss: 1.0550 - val_accuracy: 0.5491 - val_recall: 0.4509 - val_precision: 0.5976 - 107ms/epoch - 4ms/step
# Epoch 9/200
# 28/28 - 0s - loss: 0.8916 - accuracy: 0.6212 - recall: 0.4927 - precision: 0.6662 - val_loss: 1.0395 - val_accuracy: 0.5268 - val_recall: 0.4509 - val_precision: 0.5872 - 85ms/epoch - 3ms/step
# Epoch 10/200
# 28/28 - 0s - loss: 0.8725 - accuracy: 0.6302 - recall: 0.5128 - precision: 0.6730 - val_loss: 1.0281 - val_accuracy: 0.5804 - val_recall: 0.4598 - val_precision: 0.5954 - 115ms/epoch - 4ms/step
# Epoch 11/200
# 28/28 - 0s - loss: 0.8678 - accuracy: 0.6346 - recall: 0.5374 - precision: 0.6681 - val_loss: 1.0373 - val_accuracy: 0.5670 - val_recall: 0.4688 - val_precision: 0.5801 - 98ms/epoch - 4ms/step
# Epoch 12/200
# 28/28 - 0s - loss: 0.8394 - accuracy: 0.6547 - recall: 0.5341 - precision: 0.6888 - val_loss: 1.0310 - val_accuracy: 0.5580 - val_recall: 0.4554 - val_precision: 0.5795 - 93ms/epoch - 3ms/step
# Epoch 13/200
# 28/28 - 0s - loss: 0.8413 - accuracy: 0.6547 - recall: 0.5464 - precision: 0.6926 - val_loss: 1.0246 - val_accuracy: 0.5446 - val_recall: 0.4375 - val_precision: 0.5632 - 94ms/epoch - 3ms/step
# Epoch 14/200
# 28/28 - 0s - loss: 0.8230 - accuracy: 0.6603 - recall: 0.5598 - precision: 0.7096 - val_loss: 1.0197 - val_accuracy: 0.5491 - val_recall: 0.4464 - val_precision: 0.5587 - 92ms/epoch - 3ms/step
# Epoch 15/200
# 28/28 - 0s - loss: 0.8333 - accuracy: 0.6391 - recall: 0.5631 - precision: 0.6952 - val_loss: 1.0199 - val_accuracy: 0.5536 - val_recall: 0.4643 - val_precision: 0.5683 - 116ms/epoch - 4ms/step
# Epoch 16/200
# 28/28 - 0s - loss: 0.8090 - accuracy: 0.6559 - recall: 0.5654 - precision: 0.6979 - val_loss: 1.0177 - val_accuracy: 0.5491 - val_recall: 0.4509 - val_precision: 0.5611 - 123ms/epoch - 4ms/step
# Epoch 17/200
# 28/28 - 0s - loss: 0.8055 - accuracy: 0.6547 - recall: 0.5922 - precision: 0.7057 - val_loss: 1.0026 - val_accuracy: 0.5625 - val_recall: 0.4911 - val_precision: 0.5946 - 118ms/epoch - 4ms/step
# Epoch 18/200
# 28/28 - 0s - loss: 0.7862 - accuracy: 0.6603 - recall: 0.5832 - precision: 0.7035 - val_loss: 1.0093 - val_accuracy: 0.5580 - val_recall: 0.4598 - val_precision: 0.5754 - 104ms/epoch - 4ms/step
# Epoch 19/200
# 28/28 - 0s - loss: 0.7775 - accuracy: 0.6670 - recall: 0.5877 - precision: 0.7196 - val_loss: 1.0192 - val_accuracy: 0.5625 - val_recall: 0.4866 - val_precision: 0.5737 - 79ms/epoch - 3ms/step
# Epoch 20/200
# 28/28 - 0s - loss: 0.7579 - accuracy: 0.6737 - recall: 0.5933 - precision: 0.7185 - val_loss: 1.0043 - val_accuracy: 0.5759 - val_recall: 0.4821 - val_precision: 0.5902 - 87ms/epoch - 3ms/step
# Epoch 21/200
# 28/28 - 0s - loss: 0.7493 - accuracy: 0.6804 - recall: 0.6056 - precision: 0.7169 - val_loss: 1.0040 - val_accuracy: 0.5670 - val_recall: 0.4911 - val_precision: 0.5789 - 100ms/epoch - 4ms/step
# Epoch 22/200
# 28/28 - 0s - loss: 0.7407 - accuracy: 0.7028 - recall: 0.6112 - precision: 0.7303 - val_loss: 0.9903 - val_accuracy: 0.5938 - val_recall: 0.4955 - val_precision: 0.6167 - 105ms/epoch - 4ms/step
# Epoch 23/200
# 28/28 - 0s - loss: 0.7570 - accuracy: 0.6838 - recall: 0.6190 - precision: 0.7223 - val_loss: 1.0141 - val_accuracy: 0.5625 - val_recall: 0.5000 - val_precision: 0.5773 - 106ms/epoch - 4ms/step
# Epoch 24/200
# 28/28 - 0s - loss: 0.7271 - accuracy: 0.6994 - recall: 0.6313 - precision: 0.7454 - val_loss: 1.0296 - val_accuracy: 0.5714 - val_recall: 0.5000 - val_precision: 0.5714 - 100ms/epoch - 4ms/step
# Epoch 25/200
# 28/28 - 0s - loss: 0.7108 - accuracy: 0.7039 - recall: 0.6369 - precision: 0.7432 - val_loss: 1.0165 - val_accuracy: 0.5848 - val_recall: 0.5045 - val_precision: 0.5916 - 86ms/epoch - 3ms/step
# Epoch 26/200
# 28/28 - 0s - loss: 0.7145 - accuracy: 0.7006 - recall: 0.6302 - precision: 0.7334 - val_loss: 1.0178 - val_accuracy: 0.5580 - val_recall: 0.4643 - val_precision: 0.5622 - 108ms/epoch - 4ms/step
# Epoch 27/200
# 28/28 - 0s - loss: 0.7054 - accuracy: 0.7173 - recall: 0.6413 - precision: 0.7553 - val_loss: 1.0515 - val_accuracy: 0.5580 - val_recall: 0.5134 - val_precision: 0.5721 - 85ms/epoch - 3ms/step
# Epoch 28/200
# 28/28 - 0s - loss: 0.6995 - accuracy: 0.7162 - recall: 0.6547 - precision: 0.7513 - val_loss: 0.9948 - val_accuracy: 0.5625 - val_recall: 0.4866 - val_precision: 0.5860 - 106ms/epoch - 4ms/step
# Epoch 29/200
# 28/28 - 0s - loss: 0.6901 - accuracy: 0.6961 - recall: 0.6380 - precision: 0.7416 - val_loss: 1.0211 - val_accuracy: 0.5759 - val_recall: 0.5179 - val_precision: 0.6105 - 103ms/epoch - 4ms/step
# Epoch 30/200
# 28/28 - 0s - loss: 0.6850 - accuracy: 0.7151 - recall: 0.6425 - precision: 0.7546 - val_loss: 1.0299 - val_accuracy: 0.5625 - val_recall: 0.4955 - val_precision: 0.5781 - 93ms/epoch - 3ms/step
# Epoch 31/200
# 28/28 - 0s - loss: 0.6774 - accuracy: 0.7285 - recall: 0.6615 - precision: 0.7658 - val_loss: 1.0336 - val_accuracy: 0.5714 - val_recall: 0.5312 - val_precision: 0.6010 - 72ms/epoch - 3ms/step
# Epoch 32/200
# 28/28 - 0s - loss: 0.6784 - accuracy: 0.7296 - recall: 0.6827 - precision: 0.7581 - val_loss: 1.0140 - val_accuracy: 0.5670 - val_recall: 0.4911 - val_precision: 0.5914 - 109ms/epoch - 4ms/step
# Epoch 33/200
# 28/28 - 0s - loss: 0.6713 - accuracy: 0.7196 - recall: 0.6469 - precision: 0.7649 - val_loss: 1.0399 - val_accuracy: 0.5670 - val_recall: 0.4866 - val_precision: 0.5707 - 112ms/epoch - 4ms/step
# Epoch 34/200
# 28/28 - 0s - loss: 0.6505 - accuracy: 0.7374 - recall: 0.6749 - precision: 0.7724 - val_loss: 1.0299 - val_accuracy: 0.5536 - val_recall: 0.4911 - val_precision: 0.5820 - 115ms/epoch - 4ms/step
# Epoch 35/200
# 28/28 - 0s - loss: 0.6602 - accuracy: 0.7307 - recall: 0.6637 - precision: 0.7635 - val_loss: 1.0412 - val_accuracy: 0.5759 - val_recall: 0.5223 - val_precision: 0.6000 - 110ms/epoch - 4ms/step
# Epoch 36/200
# 28/28 - 0s - loss: 0.6502 - accuracy: 0.7251 - recall: 0.6693 - precision: 0.7554 - val_loss: 1.0451 - val_accuracy: 0.5625 - val_recall: 0.5000 - val_precision: 0.5744 - 108ms/epoch - 4ms/step
# Epoch 37/200
# 28/28 - 0s - loss: 0.6264 - accuracy: 0.7475 - recall: 0.6927 - precision: 0.7760 - val_loss: 1.0513 - val_accuracy: 0.5580 - val_recall: 0.4955 - val_precision: 0.5812 - 111ms/epoch - 4ms/step
# Epoch 38/200
# 28/28 - 0s - loss: 0.6382 - accuracy: 0.7318 - recall: 0.6771 - precision: 0.7819 - val_loss: 1.0485 - val_accuracy: 0.5714 - val_recall: 0.5268 - val_precision: 0.6020 - 89ms/epoch - 3ms/step
# Epoch 39/200
# 28/28 - 0s - loss: 0.6178 - accuracy: 0.7520 - recall: 0.6894 - precision: 0.7880 - val_loss: 1.0558 - val_accuracy: 0.5714 - val_recall: 0.5089 - val_precision: 0.5907 - 94ms/epoch - 3ms/step
# Epoch 40/200
# 28/28 - 0s - loss: 0.6253 - accuracy: 0.7374 - recall: 0.6816 - precision: 0.7751 - val_loss: 1.0456 - val_accuracy: 0.5580 - val_recall: 0.5089 - val_precision: 0.5938 - 97ms/epoch - 3ms/step
# Epoch 41/200
# 28/28 - 0s - loss: 0.6151 - accuracy: 0.7453 - recall: 0.7028 - precision: 0.7814 - val_loss: 1.0571 - val_accuracy: 0.5714 - val_recall: 0.5179 - val_precision: 0.5859 - 94ms/epoch - 3ms/step
# Epoch 42/200
# 28/28 - 0s - loss: 0.6139 - accuracy: 0.7508 - recall: 0.6883 - precision: 0.7897 - val_loss: 1.0779 - val_accuracy: 0.5536 - val_recall: 0.4955 - val_precision: 0.5751 - 80ms/epoch - 3ms/step
# Epoch 43/200
# 28/28 - 0s - loss: 0.5898 - accuracy: 0.7520 - recall: 0.7184 - precision: 0.7851 - val_loss: 1.0555 - val_accuracy: 0.5670 - val_recall: 0.5357 - val_precision: 0.5854 - 113ms/epoch - 4ms/step
# Epoch 44/200
# 28/28 - 0s - loss: 0.5822 - accuracy: 0.7844 - recall: 0.7330 - precision: 0.8159 - val_loss: 1.0787 - val_accuracy: 0.5714 - val_recall: 0.5268 - val_precision: 0.5900 - 106ms/epoch - 4ms/step
# Epoch 45/200
# 28/28 - 0s - loss: 0.5760 - accuracy: 0.7654 - recall: 0.7151 - precision: 0.8000 - val_loss: 1.0943 - val_accuracy: 0.5580 - val_recall: 0.5134 - val_precision: 0.5867 - 96ms/epoch - 3ms/step
# Epoch 46/200
# 28/28 - 0s - loss: 0.5838 - accuracy: 0.7553 - recall: 0.7196 - precision: 0.7844 - val_loss: 1.0716 - val_accuracy: 0.5536 - val_recall: 0.5134 - val_precision: 0.5779 - 103ms/epoch - 4ms/step
# Epoch 47/200
# 28/28 - 0s - loss: 0.5821 - accuracy: 0.7676 - recall: 0.7117 - precision: 0.8003 - val_loss: 1.0919 - val_accuracy: 0.5446 - val_recall: 0.5134 - val_precision: 0.5750 - 118ms/epoch - 4ms/step
# Epoch 48/200
# 28/28 - 0s - loss: 0.5650 - accuracy: 0.7788 - recall: 0.7352 - precision: 0.8044 - val_loss: 1.0644 - val_accuracy: 0.5625 - val_recall: 0.5357 - val_precision: 0.5854 - 120ms/epoch - 4ms/step
# Epoch 49/200
# 28/28 - 0s - loss: 0.5667 - accuracy: 0.7687 - recall: 0.7229 - precision: 0.7919 - val_loss: 1.0680 - val_accuracy: 0.5670 - val_recall: 0.5357 - val_precision: 0.5911 - 120ms/epoch - 4ms/step
# Epoch 50/200
# 28/28 - 0s - loss: 0.5720 - accuracy: 0.7620 - recall: 0.7251 - precision: 0.7983 - val_loss: 1.0705 - val_accuracy: 0.5804 - val_recall: 0.5402 - val_precision: 0.5961 - 114ms/epoch - 4ms/step
# Epoch 51/200
# 28/28 - 0s - loss: 0.5527 - accuracy: 0.7799 - recall: 0.7318 - precision: 0.8127 - val_loss: 1.1173 - val_accuracy: 0.5714 - val_recall: 0.5134 - val_precision: 0.5808 - 113ms/epoch - 4ms/step
# Epoch 52/200
# 28/28 - 0s - loss: 0.5698 - accuracy: 0.7486 - recall: 0.7151 - precision: 0.7862 - val_loss: 1.0877 - val_accuracy: 0.5670 - val_recall: 0.5357 - val_precision: 0.5970 - 118ms/epoch - 4ms/step
# Epoch 53/200
# 28/28 - 0s - loss: 0.5394 - accuracy: 0.7821 - recall: 0.7408 - precision: 0.8145 - val_loss: 1.1192 - val_accuracy: 0.5580 - val_recall: 0.5312 - val_precision: 0.5777 - 102ms/epoch - 4ms/step
# Epoch 54/200
# 28/28 - 0s - loss: 0.5265 - accuracy: 0.7866 - recall: 0.7430 - precision: 0.8220 - val_loss: 1.1202 - val_accuracy: 0.5759 - val_recall: 0.5446 - val_precision: 0.5922 - 122ms/epoch - 4ms/step
# Epoch 55/200
# 28/28 - 0s - loss: 0.5265 - accuracy: 0.7888 - recall: 0.7385 - precision: 0.8211 - val_loss: 1.1231 - val_accuracy: 0.5670 - val_recall: 0.5268 - val_precision: 0.5842 - 117ms/epoch - 4ms/step
# Epoch 56/200
# 28/28 - 0s - loss: 0.5228 - accuracy: 0.7855 - recall: 0.7508 - precision: 0.8165 - val_loss: 1.1004 - val_accuracy: 0.5759 - val_recall: 0.5491 - val_precision: 0.5913 - 125ms/epoch - 4ms/step
# Epoch 57/200
# 28/28 - 0s - loss: 0.5135 - accuracy: 0.7922 - recall: 0.7587 - precision: 0.8171 - val_loss: 1.1357 - val_accuracy: 0.5804 - val_recall: 0.5223 - val_precision: 0.5821 - 108ms/epoch - 4ms/step
# Epoch 58/200
# 28/28 - 0s - loss: 0.5108 - accuracy: 0.7978 - recall: 0.7620 - precision: 0.8237 - val_loss: 1.1212 - val_accuracy: 0.5759 - val_recall: 0.5312 - val_precision: 0.5891 - 88ms/epoch - 3ms/step
# Epoch 59/200
# 28/28 - 0s - loss: 0.4933 - accuracy: 0.8123 - recall: 0.7721 - precision: 0.8396 - val_loss: 1.1499 - val_accuracy: 0.5893 - val_recall: 0.5580 - val_precision: 0.6068 - 107ms/epoch - 4ms/step
# Epoch 60/200
# 28/28 - 0s - loss: 0.5062 - accuracy: 0.7877 - recall: 0.7609 - precision: 0.8235 - val_loss: 1.1467 - val_accuracy: 0.5625 - val_recall: 0.5312 - val_precision: 0.5862 - 111ms/epoch - 4ms/step
# Epoch 61/200
# 28/28 - 0s - loss: 0.5124 - accuracy: 0.7821 - recall: 0.7486 - precision: 0.8181 - val_loss: 1.1180 - val_accuracy: 0.5714 - val_recall: 0.5536 - val_precision: 0.6078 - 120ms/epoch - 4ms/step
# Epoch 62/200
# 28/28 - 0s - loss: 0.4904 - accuracy: 0.7978 - recall: 0.7654 - precision: 0.8184 - val_loss: 1.1258 - val_accuracy: 0.5625 - val_recall: 0.5312 - val_precision: 0.5862 - 108ms/epoch - 4ms/step
# Epoch 63/200
# 28/28 - 0s - loss: 0.4965 - accuracy: 0.8011 - recall: 0.7575 - precision: 0.8248 - val_loss: 1.1435 - val_accuracy: 0.5759 - val_recall: 0.5402 - val_precision: 0.5902 - 90ms/epoch - 3ms/step
# Epoch 64/200
# 28/28 - 0s - loss: 0.4748 - accuracy: 0.8078 - recall: 0.7821 - precision: 0.8363 - val_loss: 1.1546 - val_accuracy: 0.5625 - val_recall: 0.5402 - val_precision: 0.5902 - 114ms/epoch - 4ms/step
# Epoch 65/200
# 28/28 - 0s - loss: 0.4932 - accuracy: 0.7944 - recall: 0.7620 - precision: 0.8227 - val_loss: 1.1695 - val_accuracy: 0.5312 - val_recall: 0.5089 - val_precision: 0.5672 - 107ms/epoch - 4ms/step
# Epoch 66/200
# 28/28 - 0s - loss: 0.4734 - accuracy: 0.8145 - recall: 0.7832 - precision: 0.8436 - val_loss: 1.1937 - val_accuracy: 0.5625 - val_recall: 0.5312 - val_precision: 0.5805 - 126ms/epoch - 4ms/step
# Epoch 67/200
# 28/28 - 0s - loss: 0.4719 - accuracy: 0.8078 - recall: 0.7777 - precision: 0.8315 - val_loss: 1.1985 - val_accuracy: 0.5848 - val_recall: 0.5580 - val_precision: 0.5952 - 114ms/epoch - 4ms/step
# Epoch 68/200
# 28/28 - 0s - loss: 0.4780 - accuracy: 0.8101 - recall: 0.7810 - precision: 0.8401 - val_loss: 1.1616 - val_accuracy: 0.5714 - val_recall: 0.5357 - val_precision: 0.5882 - 113ms/epoch - 4ms/step
# Epoch 69/200
# 28/28 - 0s - loss: 0.4616 - accuracy: 0.8291 - recall: 0.7877 - precision: 0.8433 - val_loss: 1.1639 - val_accuracy: 0.5580 - val_recall: 0.5402 - val_precision: 0.5845 - 110ms/epoch - 4ms/step
# Epoch 70/200
# 28/28 - 0s - loss: 0.4392 - accuracy: 0.8324 - recall: 0.8022 - precision: 0.8609 - val_loss: 1.1896 - val_accuracy: 0.5625 - val_recall: 0.5357 - val_precision: 0.5687 - 106ms/epoch - 4ms/step
# Epoch 71/200
# 28/28 - 0s - loss: 0.4674 - accuracy: 0.8156 - recall: 0.7899 - precision: 0.8427 - val_loss: 1.2143 - val_accuracy: 0.5848 - val_recall: 0.5580 - val_precision: 0.5924 - 116ms/epoch - 4ms/step
# Epoch 72/200
# 28/28 - 0s - loss: 0.4378 - accuracy: 0.8302 - recall: 0.8000 - precision: 0.8534 - val_loss: 1.1962 - val_accuracy: 0.5536 - val_recall: 0.5268 - val_precision: 0.5728 - 110ms/epoch - 4ms/step
# CPU times: total: 13.5 s
# Wall time: 9.58 s

# %% [markdown]
# ## 5. 모델평가
# - 시각화, 평가, 교차표

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'recall', 'precision', 'val_loss', 'val_accuracy', 'val_recall', 'val_precision'])

# %%
# 학습과정 살펴보기(시각화)
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
acc_ax.plot(hist.history['val_recall'], 'k', label='val_accuracy')
acc_ax.plot(hist.history['val_precision'], 'k', label='val_accuracy')

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(bbox_to_anchor=(0.97,0.75))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 평가
loss, acc, recall, precision = model.evaluate(X_test, Y_test, verbose=0)
print('정확도 :', acc)
print('재현율 :', recall)
print('정밀도 :', precision)
# Out:
# 정확도 : 0.6270833611488342
# 재현율 : 0.5895833373069763
# 정밀도 : 0.6417233347892761

# %%
# 교차표를 위한 y_hat
y_hat = model.predict(X_test).argmax(axis=1) + 3 # 예측값
y = Y_test.argmax(axis=1) + 3 # 실제값
pd.crosstab(y, y_hat, rownames=['실제'], colnames=['예측'])
# Out:
# 15/15 [==============================] - 0s 2ms/step
# 예측  4    5    6   7  8
# 실제
# 3   0    3    0   0  0
# 4   0    8    7   1  0
# 5   3  144   51   6  0
# 6   1   47  124  20  0
# 7   0    3   23  33  1
# 8   0    0    1   4  0

# %% [markdown]
# ## 6. 모델 사용

# %%
X_redwine[0]
# Out:
# array([ 7.4   ,  0.7   ,  0.    ,  1.9   ,  0.076 , 11.    , 34.    ,
#         0.9978,  3.51  ,  0.56  ,  9.4   ])

# %%
data = [[ 7.4,0.7, 0.,  1.9,  0.076, 11., 34. , 0.9978,  3.51  ,  0.56  ,  9.4   ]]
input_data = scaler.transform(data)
model.predict(input_data).argmax(axis=1)+3
# Out:
# 1/1 [==============================] - 0s 62ms/step
# array([5], dtype=int64)
